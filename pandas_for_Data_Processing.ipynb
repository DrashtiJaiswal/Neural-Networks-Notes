# %%
import pandas as pd
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 2.2.3

# %%
students = {
    "Roll no.": [101, 102, 103, 104, 105],
    "Name": ["A", "B", "C", "D", "E"],
    "Department": ["CS", "DS", "IT", "CS", "IT"],
    "Age": [18, 19, 20, 21, 22],
    "Marks": [90, 80, 70, 60, 50]
}

df = pd.DataFrame(students)
print(df)
# Out:
#    Roll no. Name Department  Age  Marks
# 0       101    A         CS   18     90
# 1       102    B         DS   19     80
# 2       103    C         IT   20     70
# 3       104    D         CS   21     60
# 4       105    E         IT   22     50

# %%
# selecting any particular column
print(df['Name'])
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: Name, dtype: object

# %%
df[["Name","Marks"]]
# Out:
#   Name  Marks
# 0    A     90
# 1    B     80
# 2    C     70
# 3    D     60
# 4    E     50

# %%
df.loc[2]
# Out:
# Roll no.      103
# Name            C
# Department     IT
# Age            20
# Marks          70
# Name: 2, dtype: object

# %%
df.loc[2, "Marks"]
# Out:
# np.int64(70)

# %%
df.iloc[4]
# Out:
# Roll no.      105
# Name            E
# Department     IT
# Age            22
# Marks          50
# Name: 4, dtype: object

# %%
df.iloc[4,[4]]
# Out:
# Marks    50
# Name: 4, dtype: object

# %%
df[df["Marks"]>=70]
# Out:
#    Roll no. Name Department  Age  Marks
# 0       101    A         CS   18     90
# 1       102    B         DS   19     80
# 2       103    C         IT   20     70

# %%
df[(df["Marks"]>=70) & (df["Age"]>=20)]
# Out:
#    Roll no. Name Department  Age  Marks
# 2       103    C         IT   20     70

# %%
df.sort_values("Marks")
# Out:
#    Roll no. Name Department  Age  Marks
# 4       105    E         IT   22     50
# 3       104    D         CS   21     60
# 2       103    C         IT   20     70
# 1       102    B         DS   19     80
# 0       101    A         CS   18     90

# %%
df.sort_values("Marks", ascending=False)
# Out:
#    Roll no. Name Department  Age  Marks
# 0       101    A         CS   18     90
# 1       102    B         DS   19     80
# 2       103    C         IT   20     70
# 3       104    D         CS   21     60
# 4       105    E         IT   22     50

# %%
df["Result"]="Pass"

# %%
df.loc[df["Marks"]<70,"Result"]="Needs Improvement"

# %%
df
# Out:
#    Roll no. Name Department  Age  Marks             Result
# 0       101    A         CS   18     90               Pass
# 1       102    B         DS   19     80               Pass
# 2       103    C         IT   20     70               Pass
# 3       104    D         CS   21     60  Needs Improvement
# 4       105    E         IT   22     50  Needs Improvement

# %%
import numpy as np
df.loc[2,"Marks"]=np.nan
df.loc[4,"Age"]=np.nan
df
# Out:
#    Roll no. Name Department   Age  Marks             Result
# 0       101    A         CS  18.0   90.0               Pass
# 1       102    B         DS  19.0   80.0               Pass
# 2       103    C         IT  20.0    NaN               Pass
# 3       104    D         CS  21.0   60.0  Needs Improvement
# 4       105    E         IT   NaN   50.0  Needs Improvement

# %%
df.isnull()
# Out:
#    Roll no.   Name  Department    Age  Marks  Result
# 0     False  False       False  False  False   False
# 1     False  False       False  False  False   False
# 2     False  False       False  False   True   False
# 3     False  False       False  False  False   False
# 4     False  False       False   True  False   False

# %%
df.isnull().sum()
# Out:
# Roll no.      0
# Name          0
# Department    0
# Age           1
# Marks         1
# Result        0
# dtype: int64

# %%
df.fillna(0)
# Out:
#    Roll no. Name Department   Age  Marks             Result
# 0       101    A         CS  18.0   90.0               Pass
# 1       102    B         DS  19.0   80.0               Pass
# 2       103    C         IT  20.0    0.0               Pass
# 3       104    D         CS  21.0   60.0  Needs Improvement
# 4       105    E         IT   0.0   50.0  Needs Improvement

# %%
df.dropna()
# Out:
#    Roll no. Name Department   Age  Marks             Result
# 0       101    A         CS  18.0   90.0               Pass
# 1       102    B         DS  19.0   80.0               Pass
# 3       104    D         CS  21.0   60.0  Needs Improvement

# %%
df["Marks"].fillna(df["Marks"].mean())
# Out:
# 0    90.0
# 1    80.0
# 2    70.0
# 3    60.0
# 4    50.0
# Name: Marks, dtype: float64
